# %%
"""Data"""

MENU = {
    "espresso":{
        "ingredients":{
            "water": 50,
            "coffee": 18,
        },
        "cost": 1.5,
    },
    "latte":{
        "ingredients":{
            "water": 200,
            "milk": 150,
            "coffee": 24,
        },
        "cost": 2.5,
    },
    "cappuccino":{
        "ingredients":{
            "water": 250,
            "milk": 100,
            "coffee": 24,
        },
        "cost": 3.0,
    },
}

resources = {
    "water": 3000,
    "milk": 1000,
    "coffee": 500,
}

profit = 0

# %%
"""functions"""

def check_resources(order_ing):
    for item in order_ing:
        if order_ing[item] >= resources[item]:
            print(f"sorry there isn't enough {item}")
            return False
    return True

def process_coins():
    print("Please enter Coins!")
    total = int(input("How many quarters?:")) * 0.25
    total += int(input("How many dimes?:")) * 0.10
    total += int(input("How many nickles?:")) * 0.05
    total += int(input("How many pennies?:")) * 0.01
    return total

def transaction_success(money, cost):
    if money >= cost:
        change = round(money - cost, 2)
        print(f"Here is your change {change}")
        global profit
        profit += cost
        return True
    else:
        print("Sorry not enough coins put in")
        return False
    
def make_coffee(drink, ingredients):
    for item in ingredients:
        resources[item] -= ingredients[item]
    print(f"Here is your {drink}")

# %%
"""main loop"""

state = True

print("Welcome to the Coffee Machine!")
print("MENU: Espresso | Latte | Cappuccino")
print("BUTTONS: 'off' | 'espresso' | 'latte' | 'cappuccino' | 'report' ")

while state:
    press = input("Press a Button :").lower()
    if press == "off":
        state = False
    elif press == "report":
        print("Water : ",resources["water"],"ml")
        print("Milk : ",resources["milk"],"ml")
        print("Coffee : ",resources["coffee"],"gr")
        print("Money : ",profit,"$")
    else:
        drink = MENU[press]
        if check_resources(drink["ingredients"]) == True:
            payment = process_coins()
            if transaction_success(payment, drink["cost"]) == True:
                make_coffee(press, drink["ingredients"])
# Out:
# Welcome to the Coffee Machine!
# MENU: Espresso | Latte | Cappuccino
# BUTTONS: 'off' | 'espresso' | 'latte' | 'cappuccino' | 'report'
# Press a Button :latte
# Please enter Coins!
# How many quarters?:100
# How many dimes?:0
# How many nickles?:0
# How many pennies?:0
# Here is your change 22.5
# Here is your latte
# Press a Button :report
# Water :  2800 ml
# Milk :  850 ml
# Coffee :  476 gr
# Money :  2.5 $
# Press a Button :off
